# %%
import pandas as pd

# %%
df_world = pd.read_csv("world_cups.csv", index_col=0)
df_pro = pd.read_csv("pro_leagues.csv", index_col=0)

# %%
df = pd.concat([df_pro, df_world], axis=0)

# %%
df.to_csv("soccer_join.csv")

# %%
display(df)
# Out:
#                  SQUAD  SH_SHOOT  DIST_SHOOT  TOTDIST_PASS  PRGDIST_PASS  \
# 0               Alavés       286        18.3        140944         66028
# 1               Alhama       304        20.8         99993         56481
# 2        Athletic Club       325        20.4        167498         71664
# 3      Atlético Madrid       387        17.5        223757         88648
# 4            Barcelona       728        15.3        291968        107567
# 5              Levante       479        17.1        225390         92602
# 6       Levante Planas       301        21.5        139805         65995
# 7           Madrid CFF       501        19.2        184392         80754
# 8           Real Betis       288        20.2        143748         63925
# 9          Real Madrid       460        17.3        247980         90907
# 10       Real Sociedad       445        17.5        227307         87793
# 11             Sevilla       361        17.3        148239         71496
# ...

# %%
# display(df_world.head())
# display(df_pro.head())
