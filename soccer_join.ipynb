# %%
import pandas as pd

# %% [markdown]
# ### Read in World Cup and Professional League Data

# %%
df_world = pd.read_csv("data/world_cups.csv", index_col=0)
df_pro = pd.read_csv("data/pro_leagues.csv", index_col=0)

# %%
# display(df_world.head())
# display(df_pro.head())

# %% [markdown]
# ### Join the DataFrames

# %%
df = pd.concat([df_pro, df_world], axis=0)

# %% [markdown]
# ### Data Quality Testing

# %%
list(df.SEASON.unique())
# Out:
# ['2022-2023 Liga',
#  '2022 NWSL',
#  '2023 NWSL',
#  '2022-2023 WSL',
#  '2021-2022 WSL',
#  '2023 WWC',
#  '2019 WWC']

# %%
list(df.SQUAD.unique())
# Out:
# ['Alavés',
#  'Alhama',
#  'Athletic Club',
#  'Atlético Madrid',
#  'Barcelona',
#  'Levante',
#  'Levante Planas',
#  'Madrid CFF',
#  'Real Betis',
#  'Real Madrid',
#  'Real Sociedad',
#  'Sevilla',
#  'Sporting Huelva',
#  'UDG Tenerife',
#  'Valencia',
#  'Villarreal',
#  'Angel City',
#  'Courage',
#  'Current',
#  'Dash',
#  'Gotham FC',
#  'Louisville',
#  'Pride',
#  'Red Stars',
#  'Reign',
#  'Spirit',
#  'Thorns',
#  'Wave',
#  'Arsenal',
#  'Aston Villa',
#  'Brighton',
#  'Chelsea',
#  'Everton',
#  'Leicester City',
#  'Liverpool',
#  'Manchester City',
#  'Manchester Utd',
#  'Reading',
#  'Tottenham',
#  'West Ham',
#  'Birmingham City',
#  'ar Argentina',
#  'au Australia',
#  'br Brazil',
#  'ca Canada',
#  'cn China PR',
#  'co Colombia',
#  'cr Costa Rica',
#  'dk Denmark',
#  'eng England',
#  'fr France',
#  'de Germany',
#  'ht Haiti',
#  'it Italy',
#  'jm Jamaica',
#  'jp Japan',
#  'kr Korea Republic',
#  'ma Morocco',
#  'nl Netherlands',
# ...

# %%
list(df.columns)
# Out:
# ['SQUAD',
#  'SHOOT_SH',
#  'SHOOT_DIST',
#  'SEASON',
#  'PASS_TOTDIST',
#  'PASS_PRGDIST',
#  'PASS_ATT',
#  'PASS_ATT1',
#  'PASS_ATT2',
#  'PASS_ATT3',
#  'PASS_KP',
#  'PT_CRS',
#  'PT_CK',
#  'GSC_PASSLIVE',
#  'GSC_PASSLIVE1',
#  'GSC_PASSDEAD',
#  'GSC_PASSDEAD1',
#  'GSC_TO',
#  'GSC_TO1',
#  'GSC_SH',
#  'GSC_SH1',
#  'GSC_FLD',
#  'GSC_FLD1',
#  'GSC_DEF',
#  'GSC_DEF1',
#  'DA_TKL',
#  'DA_TKL1',
#  'DA_ATT',
#  'DA_BLOCKS',
#  'DA_INT',
#  'POSS_POSS',
#  'MISC_CRDY',
#  'MISC_CRDR',
#  'MISC_FLS',
#  'MISC_RECOV']

# %%
display(df)
# Out:
#               SQUAD  SHOOT_SH  SHOOT_DIST          SEASON  PASS_TOTDIST  \
# 0            Alavés       286        18.4  2022-2023 Liga        141213
# 1            Alhama       304        20.8  2022-2023 Liga         99966
# 2     Athletic Club       325        20.4  2022-2023 Liga        167473
# 3   Atlético Madrid       387        17.5  2022-2023 Liga        223772
# 4         Barcelona       728        15.3  2022-2023 Liga        291975
# ..              ...       ...         ...             ...           ...
# 51  za South Africa        16        22.8        2019 WWC         13389
# 52         es Spain        69        19.5        2019 WWC         29869
# 53        se Sweden       104        16.0        2019 WWC         41447
# 54      th Thailand        12        22.0        2019 WWC          8920
# 55           us USA       125        16.0        2019 WWC         48528
#
#     PASS_PRGDIST  PASS_ATT  PASS_ATT1  PASS_ATT2  PASS_ATT3  ...  DA_TKL  \
# ...

# %%
df.to_csv("data/soccer_join.csv")
